# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
#testing save here
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ryanzhumich/AESLC.git
# Out:
# Cloning into 'AESLC'...
# remote: Enumerating objects: 17469, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 17469 (delta 1), reused 0 (delta 0), pack-reused 17461
# Receiving objects: 100% (17469/17469), 7.36 MiB | 14.98 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# Updating files: 100% (18304/18304), done.

# %%
import pandas as pd
import os

# %%
data = {'input_text': [], 'target_text': []}
with open('/content/AESLC/enron_subject_line/train/allen-p_inbox_20.subject','r',encoding='utf-8') as reader:
  email,subject=reader.read().split("@subject")
  email = ' '.join(email.replace('/n', ' ').split()).strip()
  subject = ' '.join(subject.replace('/n', ' ').split()).strip()
  data['input_text'].append(email)
  data['target_text'].append(subject)
df = pd.DataFrame(data)
print(df)
# Out:
#                                           input_text        target_text
# 0  Greg/Phillip, Attached is the Grande Communica...  Service Agreement

# %%
def prep_training_data(output_file,input_path):

  data = {'input_text': [], 'target_text': []}
  #with open(output_file, 'w', encoding='utf-8') as train_sequence:
  for file_name in os.listdir(input_path):
      file_path = os.path.join(input_path,file_name)
      with open(file_path,'r',encoding='utf-8') as reader:
        email,subject=reader.read().split("@subject")
        email = ' '.join(email.replace('\n',' ').replace(',',' ').split()).strip()
        subject = ' '.join(subject.replace('\n',' ').replace(',',' ').split()).strip()
        data['input_text'].append(email)
        data['target_text'].append(subject)
  df = pd.DataFrame(data)
  df.to_csv(output_file, index=False)

  return

# %%
prep_training_testing_data('/content/train_data.csv','/content/AESLC/enron_subject_line/train')

# %%
train_df = pd.read_csv('/content/train_data.csv')
print(train_df.shape)
print(train_df.columns)
print(train_df.head(5))
# Out:
# (14436, 2)
# Index(['input_text', 'target_text'], dtype='object')
#                                           input_text  \
# 0  Just a note to let you know that per my conver...
# 1  Peter I can't recall if I've sent you this ove...
# 2  Esther Gary asked me to send this info to you ...
# 3  When: Thursday October 25 2001 2:00 PM-3:00 PM...
# 4  Tana - When you have the ETA amendment letter ...
#
#                     target_text
# 0              Bank of Montreal
# 1       Override letter for ABB
# 2  Customer trip for Gary Hanks
# 3                   Caithness +
# 4        TECO EnergySource Inc.

# %%
def prep_validation_test_data(output_file,input_path):
  data = {'input_text': [], 'target_text': []}
  for file_name in os.listdir(input_path):
    file_path = os.path.join(input_path,file_name)
    with open(file_path,'r',encoding='utf-8') as reader:
      email,email_right = reader.read().split('@subject')
      subject,subject_right  = email_right.split('@ann0')
      ann0,ann0_right = subject_right.split('@ann1')
      ann1,ann2 = ann0_right.split('@ann2')

      email = ' '.join(email.replace('\n',' ').replace(',',' ').split()).strip()
      subject = ' '.join(subject.replace('\n',' ').replace(',',' ').split()).strip()
      ann0 = ' '.join(ann0.replace('\n',' ').split()).strip()
      ann1 = ' '.join(ann1.replace('\n',' ').split()).strip()
      ann2 = ' '.join(ann2.replace('\n',' ').split()).strip()
      data['input_text'].append(email)
      data['target_text'].append(subject)
  df = pd.DataFrame(data)
  df.to_csv(output_file, index=False)

  return

# %%
prep_validation_test_data('/content/dev_data.csv','/content/AESLC/enron_subject_line/dev')
prep_validation_test_data('/content/test_data.csv','/content/AESLC/enron_subject_line/test')

# %%
test_df = pd.read_csv('/content/test_data.csv')
print(test_df.shape)
print(test_df.columns)
print(test_df.head(5))
# Out:
# (1906, 2)
# Index(['input_text', 'target_text'], dtype='object')
#                                           input_text  \
# 0  John I am working with Gerald and Debra on imp...
# 1  At Richard Sanders' request we ask that you fr...
# 2  Derek: Could you call me sometime this week so...
# 3  This is a reminder that the ect.enron.com ei.e...
# 4  Ginny Please see the attached guaranty. A clea...
#
#                                   target_text
# 0                 Tennessee Gas Pipeling GISB
# 1    Request for Freeze on E-Mail Destruction
# 2                              Annex A Letter
# 3  UPDATE: Supported Internet Email Addresses
# 4                        Enron Corp. Guaranty

# %%
val_df = pd.read_csv('/content/dev_data.csv')
print(val_df.shape)
print(val_df.columns)
print(val_df.head(5))
# Out:
# (1960, 2)
# Index(['input_text', 'target_text'], dtype='object')
#                                           input_text  \
# 0  Billy Lemmons & I met on Friday regarding the ...
# 1  What's up with this guy. I guess he called Mr....
# 2  Sean How's CO? I hope you are doing well. I kn...
# 3  Jeff and Stan: I lead the group responsible fo...
# 4  If you are a participant in the Enron Corp. Sa...
#
#                                          target_text
# 0                               Analyst & Associates
# 1                                         NDR Energy
# 2                                           November
# 3                        Enron's plans on 2 projects
# 4  IMPORTANT-To All Domestic Employees who Partic...

# %%
train_csv_file_path = '/content/train_data.csv'
test_csv_file_path = '/content/test_data.csv'
val_csv_file_path = '/content/dev_data.csv'

train_df = pd.read_csv(train_csv_file_path)
test_df = pd.read_csv(test_csv_file_path)
val_df = pd.read_csv(val_csv_file_path)

print('train_dv ', train_df.shape)
print('test_dv ', test_df.shape)
print('val_dv ', val_df.shape)
# Out:
# train_dv  (14436, 4)
# test_dv  (1906, 7)
# val_dv  (1960, 7)
# Index(['content', 'subject', 'file_path', 'type'], dtype='object')

# %%
dataframes = [train_df, val_df, test_df]
columns_to_drop = ['file_path', 'type']

for df in dataframes:
  df.rename(columns={'content': 'input_text'}, inplace=True)
  df.rename(columns={'subject': 'target_text'}, inplace=True)
  df.drop(columns=columns_to_drop, inplace=True)

print(train_df.shape)
print(train_df.columns)
print(train_df.head)
# Out:
# (14436, 2)
# Index(['input_text', 'target_text'], dtype='object')
# <bound method NDFrame.head of                                               input_text  \
# 0      Howdy - The early morning news on Channel 11 r...
# 1      Tracy: The Allegheny swap side letter provides...
# 2      Mike# I represent a firm which has specialized...
# 3      Rod: I will contact Frederick Broda (VP# Deriv...
# 4      I need to have a new folder set up under the n...
# ...                                                  ...
# 14431  Chris# as per our discussion# I just want to c...
# 14432  I have listed a few pertinent facts about Jeff...
# 14433  FYI. Great news. PUC "fixed" the language glit...
# 14434  I was just speaking to Edmund Cooper about var...
# 14435  Dave: Here is the agreement I received from Lo...
#
#                                    target_text
# 0                             *EMCA* An arrest
# 1                                    Allegheny
# 2                         Energy Opportunities
# 3                     Credit Agricole Indosuez
# 4                      New Folder to be set up
# ...                                        ...
# 14431                          Las Vegas CoGen
# 14432  Jeff Hodge's Election to Vice President
# 14433  Need to Review California Tariff Pronto
# 14434     London Master Swap Agreement Entries
# 14435                   Back to Back Agreement
#
# [14436 rows x 2 columns]>

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from transformers import (DataCollatorWithPadding,create_optimizer,AutoTokenizer,DataCollatorForSeq2Seq,
                          T5TokenizerFast,T5ForConditionalGeneration,TFAutoModelForSeq2SeqLM)
checkpoint = "facebook/bart-large-cnn"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]

# %%
train_df.head(2)
# Out:
#                                           input_text       target_text
# 0  Howdy - The early morning news on Channel 11 r...  *EMCA* An arrest
# 1  Tracy: The Allegheny swap side letter provides...         Allegheny

# %%
def generate_prompt(email_content, llm, tokenizer,device="cuda:0"):
    #print('generate_prompt new method called')
    # Move the model to the specified device
    llm = llm.to(device)

    #Send a clear and concise subject line for the following email.

    # Construct the input prompt
    input_prompt = f"""
                    Generate subject for below email:

                    {email_content}

                    Subject:
                    """

    # Tokenize the input prompt
    input_ids = tokenizer(input_prompt, return_tensors='pt', max_length=512)

    # Move the input tensor to the specified device
    input_ids = {key: value.to(device) for key, value in input_ids.items()}

    # Generate output on the same device
    tokenized_output = llm.generate(input_ids['input_ids'], min_length=10, max_length=128)

    # Move the output tensor back to CPU if needed
    tokenized_output = tokenized_output.to("cpu")

    # Decode the generated output
    output = tokenizer.decode(tokenized_output[0], skip_special_tokens=True)

    return output

sample_email = """Phillip,   Could you please do me a favor?
I would like  to read your current title policy to see what it says about easements.
You  should have received a copy during your closing.
I don't know how many  pages it will be but let me know how you want to handle getting a copy  made.
I'll be happy to make the copy, or whatever makes it easy for  you.
Thanks,"""

label = 'Huntley/question'

output = generate_prompt(sample_email, model, tokenizer)
print("Sample")
print(sample_email)
print("-------------------")
print("Model Generated Summary:")
print(output)
print("Correct Summary:")
print(label)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Sample
# Phillip,   Could you please do me a favor?
# I would like  to read your current title policy to see what it says about easements.
# You  should have received a copy during your closing.
# I don't know how many  pages it will be but let me know how you want to handle getting a copy  made.
# I'll be happy to make the copy, or whatever makes it easy for  you.
# Thanks,
# -------------------
# Model Generated Summary:
# Philippe: I would like to read your current title policy to see what it says about easements. You should have received a copy during your closing. Let me know how you want to handle getting a copy made.
# Correct Summary:
# Huntley/question

# %%
def tokenize_inputs(email_content):
  #print('tokenize_inputs')
  #print(type(email_content))
  start_prompt = "Generate subject for below email: \n\n"
  end_prompt = "\n\nSubject: "
  prompts = [start_prompt + dialogue + end_prompt for dialogue in email_content['input_text']]

  model_inputs = tokenizer(prompts, text_target=email_content['target_text'],max_length=128, truncation=True, padding='max_length', return_tensors='pt')
  #print(model_inputs.keys())
  return model_inputs

# %%
tokenizer.pad_token = tokenizer.eos_token
tokenized_datasets_train = hf_train_dataset.map(tokenize_inputs, batched=True)
tokenized_datasets_train = tokenized_datasets_train.remove_columns(['input_text', 'target_text'])
# Out:
# Map:   0%|          | 0/14436 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/14436 [00:00<?, ? examples/s]

# %%
print(tokenized_datasets_train[0].keys())
print(tokenized_datasets_train[0]['labels'])
# Out:
# dict_keys(['input_ids', 'attention_mask', 'labels'])
# [0, 3226, 5330, 4054, 3226, 660, 2237, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]

# %%
tokenized_datasets_test = hf_test_dataset.map(tokenize_inputs, batched=True)
tokenized_datasets_test = tokenized_datasets_test.remove_columns(['input_text', 'target_text','ann0', 'ann1', 'ann2'])
# Out:
# Map:   0%|          | 0/1906 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1906 [00:00<?, ? examples/s]

# %%
tokenized_datasets_val = hf_val_dataset.map(tokenize_inputs, batched=True)
tokenized_datasets_val = tokenized_datasets_val.remove_columns(['input_text', 'target_text','ann0', 'ann1', 'ann2'])
# Out:
# Map:   0%|          | 0/1960 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1960 [00:00<?, ? examples/s]

# %%
print(tokenized_datasets_train[0].keys())
print(tokenized_datasets_test[0].keys())
print(tokenized_datasets_val[0].keys())
# Out:
# dict_keys(['input_ids', 'attention_mask', 'labels'])
# dict_keys(['input_ids', 'attention_mask', 'labels'])
# dict_keys(['input_ids', 'attention_mask', 'labels'])

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./bart-cnn-enron-finetuned",  # local directory
    learning_rate=1e-5,
    num_train_epochs=10,
    weight_decay=0.01,
    auto_find_batch_size=True,
    evaluation_strategy='epoch',
    logging_steps=10
)

trainer = Trainer(
    model=model,
    tokenizer=tokenizer,
    args=training_args,
    train_dataset=tokenized_datasets_train,
    eval_dataset=tokenized_datasets_test
)

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer,model=model, return_tensors="tf")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1494: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='190' max='190' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [190/190 03:28, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.837000</td>
#       <td>0.265655</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.168000</td>
#       <td>0.259981</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.137300</td>
#       <td>0.265277</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.101300</td>
#       <td>0.269948</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.079500</td>
#       <td>0.283455</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.061600</td>
#       <td>0.291481</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.051700</td>
#       <td>0.309535</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.043300</td>
#       <td>0.323842</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.042000</td>
#       <td>0.322498</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.036200</td>
#       <td>0.323292</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3, 'forced_bos_token_id': 0, 'forced_eos_token_id': 2}
# TrainOutput(global_step=190, training_loss=0.1272693561880212, metrics={'train_runtime': 210.1678, 'train_samples_per_second': 6.899, 'train_steps_per_second': 0.904, 'total_flos': 392787709132800.0, 'train_loss': 0.1272693561880212, 'epoch': 10.0})

# %%
import os
import time
ver = 1
output_directory="/content/capstone/bart_model"
time_now = time.time()
model_path = os.path.join(output_directory,f"tuned_model_{ver}" )
trainer.save_model(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3, 'forced_bos_token_id': 0, 'forced_eos_token_id': 2}
# ('/content/capstone/bart_model/tuned_model_1/tokenizer_config.json',
#  '/content/capstone/bart_model/tuned_model_1/special_tokens_map.json',
#  '/content/capstone/bart_model/tuned_model_1/vocab.json',
#  '/content/capstone/bart_model/tuned_model_1/merges.txt',
#  '/content/capstone/bart_model/tuned_model_1/added_tokens.json',
#  '/content/capstone/bart_model/tuned_model_1/tokenizer.json')

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from transformers import (DataCollatorWithPadding,create_optimizer,AutoTokenizer,DataCollatorForSeq2Seq,
                          T5TokenizerFast,T5ForConditionalGeneration,TFAutoModelForSeq2SeqLM)

import os
import time
ver = 1
output_directory="/content/capstone/bart_model"
model_path = os.path.join(output_directory,f"tuned_model_{ver}" )

tokenizer4local = AutoTokenizer.from_pretrained(model_path)
model4local = AutoModelForSeq2SeqLM.from_pretrained(model_path)

# %%
print('train_df ', train_df.columns)
print('test_df  ', test_df.columns)
print('val_df   ', val_df.columns)
# Out:
# train_df  Index(['input_text', 'target_text'], dtype='object')
# test_df   Index(['input_text', 'target_text', 'ann0', 'ann1', 'ann2'], dtype='object')
# val_df    Index(['input_text', 'target_text', 'ann0', 'ann1', 'ann2'], dtype='object')

# %%
def generate(input_text):
  output = generate_prompt(input_text, model4local, tokenizer4local)
  print('output=' , output)
  return output

# %%
#output = generate_prompt(sample, model4local, tokenizer4local)
test_df['gen_subject'] = test_df['input_text'].map(generate)
print(test_df.columns)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# output= Draft of Purchase and Gathering Agreement Amendments
# output= GTC's for the Canadian FX product
# output= Change in corporate structure at Master
# output= Fence appointment for noon the Wednesday before Thanksgiving
# output= Calpine Energy Services L.P. Merger
# output= Summer intern at Berkeley - Charlene
# output= Global Operations Controller Forum - Enron Group
# output= Can you forward your calculations for September 2000 to me?
# output= Miguel needs some information on Month Belvieu Price Index and Future Prices
# output= hiit@dailymail.com
# output= Thank you for the opportunity to travel with Jeff
# output= The New York City Marathon will take place as scheduled on Sunday
# output= V&E Legal Group 1/2
# output= REMINDER - Friday 11/16/01 - Pack by 3:00 PM on Friday
# output= Weekly Project Meetings - January 7th
# output= WACM/WALC Tag #23876
# output= Your mailbox size has exceeded one or more size limits
# output= GM Operations & Accounting - Todd Hall and Cindy Horn
# output= Storage Management Questions/Storage Confidential Questions
# output= McComb Outfitters- Chris and Mertz
# output= Astros playoff tickets were much appreciated
# output= Enron Email Retention Policy: Message Location - Maximum Retention 30 days
# output= Questions you may have regarding the investigation into this matter
# output= WSCC-S Financial Positon
# output= Netting agreements - Please advise by email before you leave
# output= NA has 310#000 MMBtu parked with TGC at Dawn
# output= Gerald - What time and where is tomorrow's telephone depo?
# output= People's Energy Website and Oracle Database
# output= Whitney Whitman: I met with Sen. Bingaman and Sen. Reid last night about California energy policy.
# output= EnronOnline case-study
# output= Return to "business as usual"
# output= Letter of Interest - Michael Bridges/Bob Shults
# output= Alliance Pipeline Company and ANR Pipeline Company
# output= ETA for QTA Qalhat 13th May 0900 local time
# output= Lunch at Yank Sing at the Rincon
# output= Sara and I want to talk to Jackie McKoy and Stephanie Panus.
# output= Falcon Prospect Board Meeting - 2:00 pm - 4/8
# output= Migration to UBSW Energy
# output= Migration to UBSW Energy
# output= Financial Master Agreement (Multicurrency-Cross Border)
# output= NetClub offer includes: 1) Lucky Fares Week 43 2) Icelandair Holidays - Thanksgiving Express
# output= Adidas #671521 in size 10.5
# output= Small Appalachian producer letters sent to Enron
# output= Networking Issues - 10/1/02
# output= RSVP for this event:    Email your attendance
# output= Bank of America Foundation Donor Lunch with Tom Clausen
# output= Enron Americas Capital Book - No Profit Target
# output= Netco Meeting- January 2nd 2002- Organizing an Action Plan for the Start-up of Netco
# output= Sean Riordan @X5-4298
# output= Comments from KWI rep regarding Negotiations
# output= ISDA Interested in Emilio Pinto
# output= HR VP's - BU OTC Presentation
# output= Access to Group's Regulatory Affairs Database
# output= Can you send me a CLE form so I can get credit for Thursday sessions?
# output=  PI's Portfolio Review - Jeff
# output= Industry Policy Task Force Kick-Off Meeting
# output= Christmas gifts for the teachers at Shepherd
# output= Hi. Thanks again for taking the time to talk this afternoon.
# output= 2001 Plans were built with a 4.25% combined merit and other which equates to $348#910. 2002 Plans built with 3.75% merit equating to $307#862
# output=  memo - GSA/GSAs/GAAs Weekly Report
# output= Enron Programs - ClickAtHome and Matching Gifts
# output= GTC Counterparty Matrix Revamp
# output= REMINDER - ect.enron.com and ees.enrons.com Email domains will be decommissioned January 18th.
# output= Industrial Information Resources Inc.
# output= Non-Disclosure Agreement - GFI Group Inc.
# output= Enron Employee Meeting - 10 a.m. tomorrow
# output= Confusion regarding tomorrow's meeting concerning the above mentioned topic.
# output= Outlook Migration - October 23rd
# output= Transport-Release Contracts - CES and TRANSP
# output= Can you recommend a top notch trial lawyer (similar to yourself) at any firms in New York?
# output= MS150 pledges: Please turn in all outstanding pledges ASAP!
# output= Virus Update on Enron Workstations
# output= Power Outage Database - Daily Delivery
# output= DASH Commentary on ENA Investment in Enron Global Finance Fund
# output= Columbia Gulf NDA Changes
# output= Enron Principal Investments (EPI)
# output=  WT-2 flow study - NNG volume at Halley interconnect
# output= True Bluegrass Show in the Bay Area
# output= Counterparty Master for UK crude oil trading
# output= Do you have a policy on requests like this?
# output= Enron Conference Call: An Update
# output= You will need to reconstruct.
# output= Enron Confidential Call with Kent Shoemaker
# output= Join experts to discuss your concerns about September 11th and the issues we face as a nation.
# output= E203 final on a day other than December 10th
# output= Puget Sound Energy Inc.
# output= Hertzberg on Demand Buydown Proposal
# output= El Paso/East Coast Power LLC Proposal
# output= NAF Trading Track Dinner - Tuesday October 16th
# output= EnronOnline matrix for estate management
# output= Enron Corp. Exchange on EOG
# output= Master Contractor Services LLC ("MCLA")
# output= Sale of Napoleonville Land
# output= GMAT Class Size-8 Course # 7019-00
# output= EE&CC Green Light Application Pipeline
# output= Cabot Logistics Investor Presentation
# output= Kerr-McGee Master Agreement with Enron North America Corp.
# output= NetCO/Estate database and hardware split
# output= Trading Canadian Gas Product Ids
# output=  equity forward confirmations/Termination notice
# output= Migration Protocol for Enron Employees at UBS Warburg Energy
# output= EPMI legal group considering legal options regarding TVA breach of NERC policies.
# output= Wishing you a happy "Turkey Day!"
# output= DPR for New Year's Day reporting
# output= Status of Payment 1 and Payment 2 related documents
# output= EBS at Dell Management Committee Meeting
# output= Re-write this article - Jeff
# output= FERC approval for 4th tie-in segment
# output= Thank you for all your hard work and support
# output= Air Quality Bureau inspection of C/S 7 Mountainair and 8 Corona
# output= Los Angeles Department of Water and Power
# output= Assignment and Termination Agreement
# output= An email containing a virus is circulating the Enron messaging environment
# output= Paper mill loan "agreements"
# output= Enron Confirm/Refinancing/Assignment
# output= ISDA 510(K) Proposal
# output= Intercontinental Staffing Group - Energy Trading
# output= Strong and gusty winds expected late Thursday night through Saturday afternoon. Santa Ana Fire Weather Watch
# output=  LIBOR and Treasury interest rate curves and default probs for industrials and utilities as of 11/16/2001
# output= Enron Daytime Deals and Services
# output= Non-Disclosure Agreement - GFI Group Inc.
# output= Fault counts for May 2002 May data
# output=  HTML Basics class on September 14 - 8:30-11:30am
# output= Send an email or a letter before Monday
# output= Track and Field Day for Brownies
# output= La Plata DRA conference call - August 31 - 9:00am CST
# output= Confirm lunch with Bjorn Hagelman (Enron) 11.30-11.45
# output= COB Preliminary Meeting Conclusion/Directions- Friday/Saturday - Monday 1/2
# output= Hi, I'll be in Omaha tomorrow and back in Omaha Monday.
# output= Group Calendars for July 2014
# output= Preliminary rankings based on results of Tuesday's meeting
# output= Bike Commute Challenge Lunch on Wednesday
# output= Brent and Lynn's Strategic Management Update
# output= California PUC Letter About a High School Turnback
# output= Lexis-Nexis Basics and Due Diligence Clinics
# output= Group IT and Back-office issues - OldCo vs. NewCo
# output= hipline Meeting starting at 8:00 am (pst) - limited connections to Houston
# output= Weekly Report for the week of 05/28-06/01
# output= Congratulations on your promotion at Enron!
# output= Reed Wasden Research Daily News Update and Morning Notes
# output= Mid-year Promotions- Tom Alonso, Bob Badeer, Mike Etringer, Mark Fischer John Malowney
# output= Enron 20K Race Team Roster
# output= Powerex Cuts on Friday
# output= Weather data by region for 98 and 99
# output= Enron Credit Default Indefinite Release Letters
# output= SAP Outage - November 16-19 2001
# output= Weekly Green Light Management Committee Meeting
# output= Your mailbox size is currently 84174 KB
# output= Vessel needs 48 hours to work on steam plant maintenance
# output= Non-Disclosure Agreement - GFI Group Inc.
# output= Enron merger with Dynegy
# output= Out of Office Monday E-mail Alert
# output= JDRF Walk on October 28th
# output= 1-800-332-7979 option 3
# output= Today was a very difficult day for Enron
# output= Norm Coleman and I have an appointment to meet over energy issues.
# output= ECS ERMS Outgoing Changes
# output= Open season for CIG's Parachute Creek lateral will end next Friday
# output= Thanksgiving at Huntsville State Park: Make reservations now!
# output= By unanimous vote we will pre-determine the draft order
# output= There's a monthly birthday party thing at 300
# output= FPC and DP reputational management
# output= WINDOWS 98/BROOKLYN Edition
# output= Mosquito Control - 713-440-4800
# output=  ISO Shift Discussion List - NYISO Shift Discussion
# output= Dynegy requested a meeting with us to discuss what an "Into Product" is and how this product works with transmission.
# output= Weekly Credit Watch Listings for the week of 10/15/01
# output= EEO Europe: Energy Trading in the New Economy
# output= For the month of December you will be personally responsible for your parking
# output= 9/21 The Desk - 9/21
# output= Latest revision of the Powerball contract
# output= Euro Negotiations - John Lavorato & Louise Kitchen
# output= We do not have any executed docs to send to Morgan Stanley
# output= 2002 Mercury Mountaineer Sport-ute
# output= Gerald and Lisa's Property Settlement
# output= Meeting with Stan Horton in EB5020 on Monday September 10th 3:30 to 4:15PM
# output= Lexis-Nexis Basics and Due Diligence Clinics
# output= GMAT classes will now meet at 701 North Post Oak Road Suite #8
# output= Letter authorizing City National Bank to cancel Letter of Credit
# output= Can you buy/sell gas on EnronOnline?
# output= Credit issues raised by Enron in their comments
# output= Clay Basin inventory verification and deliverability tests beginning April 2 2002
# output= Fire Drill for Enron Center Campus December 20th 2001
# output= November PPL/Griffith Cost Contacts
# output= What happens to my existing contract with Enron?
# output= Access to West deals in Sitara
# output= Ken Lay resigns from Enron Board
# output= We are short at PGE system for Thursday and Friday 9/27-28/01
# output= Forecast for January through July
# output= News from A&K.
# output= Amendment to ISDA Master Agreement dated January 13# 2000
# output= Risk Management Rotation - Lisa
# output= Promotion happy hour for Energy Operations employees
# output= Co. 1n2 E-schedules
# output= Netting Agreements/Tables of Contents - EWS Legal Department
# output= Sally is available from 1:30 - 5:00 in the afternoon on March 1
# output= Risk Data as of 10/26/2001
# output= Nearly final docs on LLC change
# output= NewPower Energy Saving Center Offers Home and Business Analyzers To Help Consumers And Small Businesses Save Energy
# output= Happy Birthday to my good friend Sara!
# output= PIRA's extended Daily Demand Report for May 8, 2017
# output= All-Employee Meeting Oct. 23 at 10 a.m.
# output= Assistant Trader - PRC
# output= Lake Tahoe package flight from Houston
# output= Weekly Update on Dispute Resolution
# output= Hoon message from the Hoon
# output= Risk 566375 Deal - 3/3
# output= Revised draft for your review and comment
# output= Promotion Message from General Whalley
# output= Rescheduling a 2pm conference call from Houston
# output= Migration Protocol for Enron Employees at UBS Warburg Energy
# output= RAC and Credit Aggregation - Post ID Matching
# output= Consumers Energy Deal Summary - Part 1 - Part 2
# output= Outage starting anytime after 8pm and may continue until 12 a.m.
# output= Kennedy Contracts for Independant Gathering Facilities
# output= Time Management Function on eHRonline
# output= Interviews rescheduled for Monday October 29-Thursday November 1
# output= Your pride in this situation is more important to you than spending time with your pregnant wife and your daughter
# output= Open Ticket Remedy Report for Property
# output= EA Staff Meeting rescheduled due to Memorial Holiday
# output= Enmax file and amendments - Tana
# output= Can you provide addresses for the following people?
# output= JPMorgan Gas Consultants - California Gas Outlook
# output= 3rd Annual Benefit Golf Tournament- The Sunshine Kids Foundation
# output= Form F-1/F-2
# output= Research support for EAM under $750,000
# output= NetClub offer includes: 1) Lucky Fares 52 / including Amtrak Connections* 2) Icelandair Holidays 3) Business Class Special (Philadelphia to Europe w/Amtrak - Icelandair - Cellhire USA)
# output= 2 deals that are missing: 480324 and 480325
# output= UBSWenergy online trading simulation - Thursday February 7th - 0900- 1100 (CST)
# output= Carrizo Energy Master Swapping Event
# output= Enron NDA Execution of NDA between Amerex and Enron
# output= Help Wanted: slide show/video
# output= Weekly Credit Watch Listings for Co-Steel Inc. 10/29/01
# output=  NBPL PR rep: Can you help Phillip out with this
# output= I am owed?7000 from Enron
# output= West Report Formats - Factor Correction
# output= Storage guys meeting with John Defterios
# output= Return to "business as usual"
# output=  TXU Master User Contact Changes
# output= PWR-GAS-LT-MGMT-PRC
# output= SuperHotOffers.com
# output= INGAA Annual Security Analysts Conference - Panel on natural gas supply - 8:15-10:00 a.m. Friday July 13
# output= Siemens Layoff from Atlanta
# output= LCRA Capacity Pymts -  275298- 275298
# output= Viviana's concern she was not being properly guided
# output= Central Puerto has been unresponsive to requests for original documents
# output= Duke appears to have acquired the counterparty
# output= NAI Interview Lunch for ENA Trading Track candidates Thursday 12:45pm
# output= Comments on ISDA Rider 7 and LC language
# output= Power Outage Database - Daily Delivery
# output= RAC Risk Trading Policy - Business Unit and Commodity DPR's
# output= Enron Energy Services May 30 11:30 a.m.-12:30 p.m.
# output= Hoegh GALLEON 24TH APRIL 1200LT (1400UTC) ETA Algeciras 30th.
# output= Koch and I need to get this Koch thing resolved ASAP - the sooner the better
# output= Recruitment Announcement - DG
# output= Enron Principal Investments (EPI)
# output= ENRON "Breakfast Club"
# output= East Desk Pipelines - National Fuel and Gas and TCO
# output= Enron Global Services (EGS)
# output= Assignment Changes to the consolidation agreement
# output= You are scheduled to interview for the Trading Track Thursday
# output= Billing for October 28 2001 settlements
# output= Can you please provide an Index quote for the following volume?
# output= Energy Club Program for the academic year 2001-2002
# output= Final version of documents on EOTT system
# output= Reschedule your appointment with Mr. Lay
# output= Enron Management Committee Invitation To Board of Directors Meeting
# output= You are scheduled to interview for the Trading Track Thursday
# output= Global Master for Pushkar's FX Trading
# output= Power Outage Database - Daily Delivery
# output= Change in volume on deal 549411
# output= Sam Foelber's birthday party
# output= Transwestern CPUC proceedings - Key Dates and Status -  attached
# output= EnronOnline Contract Management Services Agreement
# output= Amendment to ISDA Master Agreement between ENA and RBC
# output= Enron Holiday Party Cancellation
# output= Aquarius: An agreement or legal matter improves today.
# output= Assignment of Facility Audits to Corporate Public Affairs
# output= Port summary for Inmarsat 1.1xls
# output= CT/Paribas Deal No. EA7484.3 and EB3772.3
# output= Latest attempt at satisfying the "ill-defined"
# output= ECN 6116 Meeting scheduled for Monday November 26th 2001 11:45am-1:00pm
# output= APX January 2 2002 - 17mw
# output= Ken LayDear Ken: I just wanted to send you a quick email to say I support you
# output=  TAGG and ENPOWER Futures Deals successfully entered
# output= Puget Sound Gas Purchase from Kingsgate
# output= Lexis-Nexis Basics and Due Diligence Clinics
# output= EOL Report troubleshooter
# output= Migration of UBSWE Employees
# output= Form for equipment going into TurboPark
# output= Key contact information for applications support
# output= Enron Support for Non-standard Internet Email Address formats
# output= Free Weekly Discussion of the Markets "FAST BREAK" by Jim Wyckoff and Dave Hightower
# output= Draft Release from Enron/JPMorgan/Citigroup
# output= Free 2001 Family Law Seminar scheduled for June 22 canceled
# output= You are beautiful# confident# and intelligent# and yet you don't act like you know that.
# output= Body Shop will be closed December 15 payroll run
# output= SpaceX Response to GE Power Plant Application
# output= Romance in Paradise with our Travel Team
# output= US Gas EOL Deals as of 10/31/2000
# output= Chargers Game Schedule for Sunday, September 8
# output= Enron Affiliate Transfer of Rights and Debts Agreement
# output= Global Power Trading Seminar - Greg
# output= Grumps came through angioplasty with flying colors.
# output= VEPCO Out of Office
# output= List of projects for the "quant" team
# output= Memo/Comments - Steve Kean/Ken Lay
# output= Established criteria for evaluating prospects for retail service state-by-state and by major LDC
# output= Assignment and contribution agreement - ECS LLC
# output= First employee move into Enron Center South
# output= Hi. How are you doing?
# output= Soccer practice tonight or Sunday?
# output= Home Address and Phone Number Required by HR
# output= Legal Budget Reports - QBRs
# output= Counterparty Deals - FT-Can-Gone FT-Cand-Termin
# output= Environmental Due Diligence Report for Northwest Natural Gas Company (NWNG)
# output= GISB Amendment concerning confirming party
# output= Enron Corp. "Deal Report"
# output= Your mailbox size is currently 88704 KB
# output= Management Committee Meeting: Monday August 27, 2001 - 11:00 a.m.
# output= Congratulations on your promotion to managing director!
# output= UBS HR Presentation - Thursday 1/24/02 - 9:00am
# output= Livelink Resources for the HR Community
# output= Change in Headgear for the Army's Birthday
# output= 5th Anniversary Gala - Teala's
# output= Members of the Program: An Update on Current Events
# output= REMINDER- I will be out on vacation this Monday
# output= Foreign & Domestic Counsel Database - NEW: Please provide any new information
# output= Help desk Contract Contract Dispute
# output= ISDA "ISDAize" 8/29/99 fax
# output= "It's a Girl!" May 24-26 at 8:00 p.m.
# output= Fuel cell testing for CRRA approval
# output= CIMA Energy IT agreement with TW
# output= Deal confirmed as a regular forward
# output= Legal research and related knowledge activities and products are traditionally not a great source of efficiency and expertise. In-house counsel are frequently asked to provide their companies legal advice in a vast array of legal areas. LRSolutions helps companies reduce outside legal costs while retaining qu! al! ity and value
# output= Fourth Annual Peterson Ethics Lecture: William Drayton - Ashoka Founder
# output= New user notes:  14(a) - Cherrypicking
# output= Happiness lies for those who cry and those who hurt
# output=  ISO Outage Communication Protocols
# output=  CGAS Ticket Changes - August 31st
# output= Christi conference call on November 28th - Details below
# output=  discount on ICTS contract #1.8793
# output= You can call on me anytime and under any circumstances--no compensation expected.
# output= Pheasant hunting trip in Western S. D.
# output= Osteria D'Aldo
# output= Transport contracts on CNG for July
# output= Next week we'll recalibrating dummified regression models for Enron Credit pricing system
# output= Wishing you a safe and happy Thanksgiving
# output= E-Opportunities in Europe
# output= National Fuel Services on IAS
# output= New Power Bookout - 597332
# output= Draft Agreement Revises for your review.
# output= Help from all over the world is appreciated!
# output= 2nd quarter Transwestern/SoCal PCB mgt. committee conference call
# output= Bidders error on Ebay
# output= Physical positions in NCD for term
# output= Hoegh Galleon #12-May-12 (GMT -8:00)
# output= Weekly Gas Policy Review - Meeting 3:30pm ET
# output= Enron CEO Ray Lay asks if reverse stock split possible option
# output= Duke confirm on John Miller
# output= ENA legal opinion on M.A.R.T. financial swap
# output= Gomez Title V Permit No. O-00754
# output= Dow Jones COB Sunday Index
# output= First draft of the swap for Raptor 2
# output= Watch Report for Principal Investments 8/31/01
# output= Financial Trading Law Group Meeting on Form Integrity
# output= Netting for Forest Oil and Noble Affiliates
# output= Marketer/Originator/Mid-Marketer
# output= DRI v ENA - 6/28/02
# output= Policy/Insurance Requirement on Exhibit E
# output= ICE Help Desk - ASTROS - The Answer to Your Secret Question
# output= ET&S employee David Foti accepted a position at EES effective August 1 2000
# output= Tyson is working with the Governor's office on a possible meeting
# output= Family of RAC employee was flooded out of their home in June
# output= Engineer responsible for project reporting - Rebox
# output= ECG Fuels Response to Docket No. R/E/S/16-01-01
# output= How do we set priorities in an uncertain world?
# output= Problem with PGAS and TMS
# output= Management Committee Extended Meeting - January 23
# output= Dierdre McCaffrey
# output= Thanks for all you've done for Enron
# output= i need to send jennifer a shower invitation - i lost the zip code - duh. can you forward me your zip code?
# output= MAILSweeper inbound and outbound servers
# output= United Cogen Inc.: Follow up on some information
# output= Beth is a great addition to the team
# output= First draft of CreditStream settlement agreement
# output= PGG 3rd estimate for ENA
# output= Hey, I just wanted to see if we're still on for Saturday night.
# output= Recruitment firms and other media inquiries regarding Enron
# output= Enron ISDA Revised 9.26.01 Schedule
# output= Lexis-Nexis Basics and Due Diligence Clinics
# output= Crescendo Energy LLC
# output= I will be attending a funeral in Austin on Thursday
# output= Man mooning me in a humorous manner
# output= Hey guys - sorry to hear about your dog
# output= Movers coming in this weekend to box up for the big move.
# output= NYISO ER01-3001: Request by NYISO to extend $1000/MWh Bid Caps on certain NYISO adminstered markets
# output= Enron Pay stub Form Required by October 15 2001
# output= CADER 2001 DG Conference: Good news!
# output= Full text of the Financial Times (FT)
# output= Enpower Position Manager Demo - Thursday August 9th - 11:00am
# output= Change effective 9/7/2000
# output= Your Name and Parents Required by OSI
# output= Hess Energy Netting Contract Management
# output= Matagorda County Fair & Livestock Association
# output= List of issues discussed based on VEPCO revisions
# output= Enron Stock Trading on NYSE and ESOP
# output= No excess injections for the rest of the week. IT between Niagara and Leidy 80#000dth
# output= Happy New Year from "Sue"
# output= EEI Contract - EEI Contract
# output= Latest report on the DYNEGY/ENRON deal from CS First Boston Research
# output= Environmental records of Transredes and the Government
# output= What needs to be done with Duke on a first priority basis
# output= Migration of UBSWE Employees
# output= Coming Full Circle: A Plausible Future for Power Generation
# output= Recruitment firms and other media inquiries regarding Enron
# output= Assignment Update - 1/2
# output= Roster additions/Losers - 1/2
# output= You are a superior executive and philanthropist of the first order
# output= SC for Bay Environmental Management - starting on July 3rd
# output= You need to do one thing when you pack for your trip to London...BRING YOUR WALLET
# output= TETCO demand charges on the ECT Trans worksheet were not subtotaled.
# output= Assignment Credit Worksheet from 5/16/00
# output= USGT Amendment to TW Contract
# output= Gates indicated a desire to become a member of The Business Council.
# output= Widows 2000 migration - 4/16-4/17 - Profile Interviews & Pilot Process
# output= New Access Card InformationDear Colleagues - Good News
# output= Enron to cut one-fifth of jobs at broadband unit. Job cuts due to network completion, slow demand for streaming media.
# output= HTC Energy Initiative/McKinsey Symposium
# output= Enron North America Gas Purchase Agreement
# output= Backup Worksheets - README & PDF
# output= 2001 Accounts Receivable Management Team Meeting
# output= Regulatory attorney at Constellation
# output= Enron Email Retention Policy: Message Location - Maximum Retention 30 days
# output= The Main Bed & Breakfast Inn in Palacios, Texas
# output= You still have the following files: Dynegy Canada, SMUD, NYSE&G
# output= Bankruptcy of Drexel
# output= Zachary's Memorial Fund
# output= Enron CorporationDear Employees: I want to thank you for your continued support.
# output= Sale of 330.12 acres - DASH
# output= Changes per Mike Swerzbin - 516611-516651
# output= LJM/Raptor related valuations
# output= EES and ECS Master Firm/Purchase
# output= Comments from ISDA to Marie Heard
# output= SAP Response Time Update - October 1st
# output= Perry Gas & Energy Marketing Group
# output= PUC ruling on First Energy merger and PPL RFP
# output= Thanks for your willingness to sign these things
# output= Financial deals in the name of Aquila will change to Utilicorp United Inc.
# output= ETS Half Day Staff Meeting- August 15
# output= STP meeting tomorrow morning at 10:30 am.
# output= Baker & Botts bankruptcy counsel - David Burns
# output= RTO update:   Christi Nicolay and Susan Lindberg
# output= Comments on Rod Allen's Farewell Poem
# output= Make sure your OG&E curves and scalars are in good shape.
# output= All physical retail volumes in Sitara for the East Desk
# output= Shirt Sizes: Small - Medium - Large - X-Large
# output= Global Contracts Group's assignments for the month of November 2001
# output= Last Call for Fundamentals of Electricity
# output= Mia...Happy Birthday!
# output= Enron Stock Trading on NYSE and ESOP
# output= Remaining Projects: Painting sunroom, bedroom furniture and more
# output= ECC documents held up by Instinet.
# output= Pacific Gas & Electric Counterparty ISDA Master Agreement
# output= Coming Full Circle: A Plausible Future for Power Generation
# output= ICAP Manual Changes - 8/27/01 8/28/01
# output= Enron associate concerned about the partnership/CFO situation
# output= List of Required Documents/Deletions for Questar
# output= Review of Questar and Sonoran open season docs
# output= Your reservation for this Travelocity reservation has been issued. The FAA now requires a photo ID and a printed passenger receipt or paper ticket for travel.
# output= Rob McCrory will be visiting us next week during Legal Conference.
# output= Bush administration's economic officials have been ineffectual - Lawrence Kudlow
# output= Leadership Development Committee Chairpersonality letter to David Parquet
# output= Public Service Electric and Gas Company (Public Service)
# output= Meeting with Christian Yoder (Portland - 2 hours earlier than CST) - "Washington State PUD's"
# output= Join experts to discuss your concerns about September 11th and the issues we face as a nation.
# output= Enron E-mail Restrictions
# output= Recruiting is a challenge for Haas this year. Career Center wants to help students succeed.
# output= Demand Charge on Penn Fuel Capacity - 6.423
# output= Cal Outdoors January 19th - Washington State vs Cal
# output= Office Hours for January 1-21
# output= Firm Purchase/Sale Agreement for Enron LNG
# output= Enron settlement with Dynegy over Northern Natural Gas
# output=  FT Contracts from October 2000 through September 2001
# output= Business Plan for 2000 and 2001
# output= Origination Track candidates - List of potential candidates.
# output= Assertion provision - D.C. vs. Texas
# output= Back at work after a week off!
# output= Edison/Brattle Group presentation on California Gas Price Rant
# output= Projects you may want us to work on
# output= Your order 5639809 has been shipped.
# output= Enron Pay stub Form Required by October 15 2001
# output= Juvenile Diabetes Foundation Gala
# output= Assignment of electronic mail destruction requests
# output= A meeting has been scheduled to discuss Texas General Land Office Management Proposal
# output= November 1st - Interviews for ENA Trading Track - November 1st
# output= Mondavi Guest List Tasting
# output= National Steel's 3#000 MMBtu per day contract
# output= Hi from your Aunt and Uncle
# output= Problem mapping to P: and other drives in Terminal Server Sessions resolved
# output= Sampling Update - Q3 2013
# output= Redline for you to look at
# output= BEAR Holiday Fundraiser- November 5-8- at Enron Lobby
# output= REMINDER - ect.enron.com and ees.enrons.com Email domains will be decommissioned January 18th.
# output= Kobra Permission Changes - 713 853-9225
# output= EFS Update for Monday, May 8
# output= Reciprocal Force Majeure language
# output= Rotation Opportunity in EBS Origination Americas
# output= Migration of UBSWE Employees
# output= PRC accomplishments for the first half of 2000
# output= REMINDER- November elections
# output= RWR Daily News Update & Morning Notes - November 16th - The Prometheus File
# output= Counterparty Demonstrator Demonstration
# output= Kori asked us to kill all the deals between her portfolio and other portfolio due to bankruptcy.
# output= Projects underway at Enron Financial Services Group
# output= Stargate Manager - Client Support
# output= Movers coming in this weekend to box up for the big move.
# output= New posting procedures effective November 1st 2001
# output= You were in Rio last week...how are you?
# output= YMCA baseball game at the YMCA
# output= Mariner Exploration Partners LP (Mariner)
# output= Comments on the Graduation Scenarios
# output= Enron merger with Dynegy
# output= Your mailbox size is currently 90247 KB
# output= Can you make a copy of the most recent draft and get on my calendar before Monday so I can discuss?
# output= Web Trader - OATI Examine Web Trader's Specification & Demonstrations 9:00am - 11:00A - 2:00pm
# output= There are several pieces of equipment that are set up on the 30th Floor and on our floor for the Disaster Recovery Team. DO NOT TAKE# BORROW OR USE this equipment.
# output= Ripley's Attraction Sale
# output= Enron GIS Update Your GIS Profile for VP and MD
# output= More guidelines for GRMS text files
# output= Pollution training for facilities with pollution prevention plans.
# output= HR-Bi-Weekly Leadership Meeting - Tuesday October 23 - 8:30am
# output= Texas Eastern's request to hold capacity on another pipeline is granted
# output= Hi, I am the CEO of a Houston based Microsoft technology consultancy called ESX Engineering.
# output= Nothing from Ben yet - extension letter possible.
# output= If a legal transition team is formed# I would like to be considered for membership.
# output= The FBI is currently conducting an investigation in the building
# output= Bridgeline receivables
# output= EcoElectrica's 2002 Winter Cargo
# output= PG&E GTN maintenance at unit 7C
# output= PRC Offsite December 13th
# output= contact list for UBS Warburg Energy Operations
# output= GM Operations & Accounting - Todd Hall and Cindy Horn
# output= Defensive Driving Certificate Submittal Due Diligence
# output= Transalta at SP 15 and Mead 230
# output= Out of Office Alert - Thursday Oct. 4 - Monday Oct. 8
# output= New Power Purchases and Sales for November
# output= Enron Response to Entergy-Koch Settlement
# output= Monday-Tuesday 12:00-12:00am ET (GMT-06:00)
# output= Updated EOL consent agreement for EOL information
# output= Houston Pipeline Company (HPL)
# output= May Site Total and Power Outage Report
# output= UCU Credit Decision - October Estimate
# output= Counterparty Refusal to See GTC
# output= Patty Deas is joining the Technical Services Team
# output= Effective 2/1/02 a new company called ENNG will go into effect called 179E.
# output= Enron Center South Occupancy Guidebook
# output= Lexis-Nexis Basics and Due Diligence Clinics
# output= Legislature likely to postpone recess and work through weekend
# output= Risk Management Class - November 15 & 16 2001 8:00am - 5:00pm
# output= BPA values as of 12/17/2001
# output= Can you call Bob Bowen and give him the sign off?
# output= Changes in Enron Government Affairs Organization
# output= PG&E Gas Transmission Northwest Puts New Line in Service
# output= STCA Deal 564094 - Real Time Correction
# output= National Bar Association Convention sponsorship Packet
# output= ESA Document Draft-Read and Respond - Ben
# output= RAC Capital Partners Inc.
# output= New UBS Warburg office space Q&A
# output= Associate & Analyst Recruiting Events require ENA participation at Manager level
# output= Promotions to Director and Senior Director Lunch
# output= ECO- dependent Application for EOL
# output= Superheater on stb boiler inspected last night
# output= Congratulations on your new job!
# output= Enron Corp. is a member of the Official Unsecured Creditors' Committee appointed in the Pacific Gas and Electric Company bankruptcy case
# output= Virus Update on Enron Workstations
# output= Can we reschedule the phone call for 9 am (Houston) or 11 am (Sao Paulo) on Friday# Sept. 17?
# output= Vacation from 12/17-12/20
# output= Epsilon Property & Services Corp
# output= Enron Wind Interim Chief Operating Officer
# output= South American Legal staffing issues - Jim
# output= BoD meeting notes - Chewco/Marlin and Whitewing
# output= Survey - Key Concerns of Enron Employees
# output= Hi from the Trading Floor!
# output= ESA Discussion Draft Change Order #3
# output= Power Outage Database - Daily Delivery
# output= Short Term PPA template for North America and Canada
# output=  Ratings Outline for the upcoming school year
# output= West Power Data Gathering Initiative - Jason and Co
# output= Reed Wasden Research Daily News Update & Morning Notes - November 16th - November 25th
# output= Report  Response Time: 11/11/2001
# output= Title Transfers - Consumers Energy
# output= IPG/Enron/Coastal/Engage Reps
# output= Survey of 5142 Employees by Enron Business
# output= Analyst Orientation Happy Hour
# output= Can you send me the info for TW Commercial for the 3rd CE and TW 2002 plan detail?
# output= any info that would boost my B.S. factor would be much appreciated.
# output= Can you get Bill added as a VP of Enron North America?
# output= Altra declined to provide secondary storage platform for SoCal and PG&E.
# output= Deal Entry and Valuation Problems
# output= Excel files available at G:Common/LNG/Hoegh Galleon
# output= The Pulp Weekly Meeting will now be held in video conference room ECS 04075
# output= Daily Log as of 08/20/01
# output= Board of Directors meeting: November 19th 2001 - 5:00 P.M.
# output= Tasks for the Unify Team
# output= Some machines may not have received the latest Norton AntiVirus update
# output= Analysis of a publicly-traded company
# output= TBD on Tuesday morning meeting in Sacramento
# output= Assignment changed several times - please confirm attendance via e-mail
# output= Enron Calculation Agent - June 2nd Draft
# output= Total Return Swap Confirmation - Sec. 3.2 - Part 5(l)
# output= Lead attorney on Project One - OFCCP "glass ceiling" audit of ENA and Enron
# output= Virus detected in Enron Email Environment
# output= EGS Management Committee Meeting on October 31st
# output= Weather updates from the Meteorologists
# output= Amendments to counterparties via Profile Manager
# output= Changes to Autohedge on EnronOnline effective Monday, October 22 2001
# output=  TW Negotiated Rate Settlement Hearing - EBB Modification
# output= Can you please set this new location up# Nipsco/NGPL?
# output= EnronOnline Capacity Bids and Contracts
# output= Duke and ENA Master Trading Agreement
# output= These companies will make good cash on cash returns in the short run
# output= Final P&L for 991
# output= Help Wanted: David Oxley
# output= Comments on Enron Coal Activities and Changes in the Industry
# output= Brent Dyson's ENA Assignment in London
# output= ECT or ENA Investor Relations Manager
# output= All day meeting on May 31? Any possibility of rescheduling?
# output= CSA Annex Language on Custodians and Qualification
# output= An ENA employee wrote a book that was published in Russia
# output= Risk Officers Roundtable Meeting Postponed until January
# output= v2.0 of the ClickAtHome Portal is now available! Log into www.clickathome.net now from work or home! Access the PEP System through the portal!
# output= Enron Center Security Update - October 25th
# output= Business Continuity Planning (BCP) Seats on 30th and 31st Floors
# output= Delta/Hancock/Delta/Freshfields transaction
# output= Lexis-Nexis Basics and Due Diligence Clinics
# output= Haas Voice Mail Outage
# output= ESA MOU for sale of LMs and ABB equipment
# output= ECT Europe Account at Bear Stearns
# output= Appeal for Candidacy form
# output= City of Huntsville Counterparty Name
# output= You are leaving Enron.
# output= GE Contract Review - Austin Power Company
# output= Status of NYMEX Seats
# output= Real Time Group - Enpower
# output= Hi Lee, I need to get with Lee Johnson.
# output= NAGA Average Deal Breakdown for EOL
# output= Outlook Migration - April 17th
# output= Southern's West Gas Trading Manager
# output= Jornada training for Sallybeck
# output= GISB with Tenn. Gas
# output= FERC Approval of 6th segment to gate valve 5 at Medicine Bow
# output= Enron employees eligible for Metro Bus Passes or Woodlands Express Pass
# output= Home Address and Phone Number Required by HR
# output= Risk Orientation for GRAPHIC IMAGES
# output= All-Employee Meeting: 10 a.m. - 10:30am Tuesday
# output= Final 2000 i/s package for Wes
# output=  FMLA and Sick Leave Policy - Sarah
# output= Enron Response to a Procter & Gamble Lender Application
# output= Comments/Reviews/Questions/Thanks
# output= CES on Trco: I'm missing several contracts
# output= Form of Termination Agreement for "oops trades"
# output= Lexis-Nexis Basics and Due Diligence Clinics
# output= New Master Financial Agreement established in Global Contracts - EOL
# output= EEOS / NEPCO weekly project update for week ending October 12 2001
# output= Changes to the Enron Corp. Savings Plan effective November 29
# output= List of counterparties contact information - please see the list below.
# output= Nuclear Outage Update 7-Day Forecast
# output= UBSWenergy online trading simulation - Thursday February 7th - 0900- 1100 (CST)
# output= Your subscription to California Energy Markets is expiring December 21 2001.
# output= Recall requests for rehearing in Southeastern RTO proceedings
# output= A new dial in number set up for a conference call
# output= GISB for Docket number GISB-01-17-17
# output= New "Plan B" State Response to PG&E
# output= Draft Owner's Engineer Agreement for Gulf Power transmission facilities
# output= Enron acquisition of Suncor Energy
# output= Plan headcount for December 31st 1998 through 2001
# output= NYISO Availability for 19 August 2001 real-time market
# output= How was your holiday? I still feel like shit.
# output= On-campus mail distribution resumed this afternoon (11/14/01)
# output= RATS 5.0 Site license for Houston/unlimited
# output= Save a copy of each P&L to Netco\2002\0102\region#0102
# output= Enron Gives All Employees a Home Computer
# output= RMT vs. ENA on EOL
# output= UBSW Energy Launch Timeline: Hart-Scott-Rodino Application
# output= ModReg - Enron's Argentina Model
# output= Radio broadcaster sues to overturn Florida's ban on "dwarf tossing" Contest in which dwarfs don harnesses and allow bar patrons to hurl them through air
# output= United Way Executive Solicitiation
# output= Aims to apply drag reducing agent to La Plata to Bloomfield pipeline
# output= Enron at Virginia Power: Legal issues
# output= New responsibility for 7:30 meeting: Go over all west outages by region and fuel type
# output= First offer on our house fell through. Second offer on the house is on the way.
# output= PUC Order on Direct Access surcharge Changes
# output= What Were You Thinking? - January Deals
# output= NFL Draft May 8th - Chicago Bears
# output= Enron Energy Services LLC (EES)
# output= Quick list of what it takes to pull GRMS positions
# output= Statoil ISDA Master Agreement with ENA
# output= ENA desires to re-establish its account with Paribas
# output= Enron Programs - ClickAtHome and Matching Gifts
# output= Comments on SCE advice letter 1586-E
# output= M&M Bomchil invoices
# output= Enron Pay stub Form Required by October 15 2001
# output= CPCN Pronounce
# output= MNF Transportation/Invesco Field Tours
# output= Kenneth Lovejoy has joined Enron Corp. EES
# output= Join Dr. Joel Bloom for National Fitness Week on eSpeak!
# output= Changes to Autohedge on EnronOnline effective Monday, October 22 2001
# output= You should receive your tickets by +/- 2:00p today.
# output= Counterparty Negotiations with CP
# output= Enron merger with Dynegy
# output= PRC breakfast with Cheryl Kuehl and Charlene Jackson - November 30 8:30 a.m.
# output= Final distribution list for MDs and Robert Knight
# output= Conflict on June 2/3
# output= hi-just a quick note to let you know that you still have an employee who is confident something good will prevail
# output= Cheryl: I am open any time on Jan. 8# 9 or 10
# output= Sabic Americas Inc. Credit Approval
# output= Legal Call from Mike Kent and Mike
# output= What's going on at Enron?
# output= List for 1/24/00
# output= An explosion and fire at Enron's Teesside power facility in England
# output= ENA guaranty - Sheila Glover
# output= Amigos on the ground
# output= Steag's online ad for PR rep
# output= Voltage limits and voltage-collapse limits are studied off-line using detailed AC power-flow techniques. SCUC/BME and SCD will secure the system accordingly.
# output= CIG Worksheet for February
# output= Enron Programs - ClickAtHome and Matching Gifts
# output= Enron/Dynegy Hiring Protocol
# output= SEPTEMBER BIKE COMMUTE CHALLENGE
# output= Comments on clause regarding letters of credit
# output= We have been doing surprisingly well in the press
# output= FX Book Q&A - 1/2
# output= Professional Development Program for Senior Administrative Assistants
# output= Outstanding business expenses - iPayIt/XMSM
# output= Meeting to go over some of the deals that closed last year.
# output= TP2 buy from Gulf 1 at St 65
# output= 3rd Quarter Losses: $40.23 million
# output= SEC inquiry into LJM transactions with Enron
# output= Thanks in advance to all ENA employees who will join me in the office on January 1st 2000.
# output= Sukran and Mark, Welcome back from Turkey
# output= Out of office next week for my wedding
# output= meetings with Fish and Game on 3/16
# output= Tribal Banker/Broker contact
# output= Enron and UBS have entered into an agreement to sell certain assets
# output= Trip Reports: Stamford Trip Days In Mgr.
# output= Hedge strip file - R2/R1
# output= Confirmed lunch and office visit
# output= Non-Disclosure Agreement - GFI Group Inc.
# output= ACacia Natural Gas Filing for Section 311 Rates
# output= EC2 Legal/Credit Committee Meeting
# output=  DB credit issues with S&P
# output= Enron Email Retention Policy: Message Location - Maximum Retention 30 days
# output= Mid-to-executive level Marketing/Business Development
# output= Kinder Morgan/Morgan Stanley JV
# output= You can call us at 5:00 p.m.
# output= U.S. government is investigating hundreds of relatives of those involved in 9/11 attacks.
# output= PRC Meeting- A&A ranking/Feedback Form Gatherings- 8:00am tomorrow
# output= FERC Limits Public Access to Pipe# Transmission Maps
# output= Natural Gas Index for Thursday, November 29
# output= CES-Cove Point
# output= Move of printer to litigation war room
# output= Enron Corp. Savings Plan participants: Read this message carefully!
# output= Enron Participation in the Frank Gehry Architect Exhibition at the Guggenheim Museum
# output= Associate Program Resume Delivery & Interview - May 23rd
# output= Bobby Reynolds table for April 9th
# output= Update on Due Diligence Teams for Acquisitions
# output= SECONDARY POINT PRIORITY ALLOCATION - NO REFUSAL REQUER
# output= ISDA Schedule for referenced entities
# output= EnronOnline Rejection Letters from Credit
# output= Managers Level Impact and Influence Program
# output=  Mercator Energy Incorporated and Energy West Inc.
# output= ENA SWAP FORMS 2001-01-01
# output= Comments from contact about Donald Mellencamp
# output= Brokerage Agreement Memo/Updated List Meeting
# output= Park N Ride on the Sun Devil Pipeline
# output= ISDA Lunch Controversy
# output= Seminole Energy Services L.L.C.
# output= Power Outage Database - Daily Delivery
# output= 7th Annual Golf Tournament benefiting Klein High School Drill Team
# output= Draft Public Statement on Project Stanley - Seeking Advice of Counsel
# output= Can I please be provided with copies of the Dynegy documents?
# output= Counterparty Disclosure - 8/8/00
# output= Rice Recommendation Form - Tuesday the 21st
# output= Money Market List for 01/07/02
# output= How do you want your name to read on corporate documents?
# output= Your e-mail has been quarantined at MailSweeper
# output= Kase and Company termination letter from Kase & Company
# output= Team gathering documents in response to subpoenas from Congress and DOJ
# output= Assignment of FPL trade - FPL
# output= Migration tips and reminders for UBSWE
# output= You're as cute as a junebug a-buzzin' overhead.
# output= RAC fiduciary duties
# output= EnronOnline Gas Logistics Manager
# output= We are closing our account with Pagenet.
# output= Book Ids for each trader listed below:
# output= Strong earthquake occurred 135 miles (220 km) WNW of Arequipa, Peru at 7:53 AM MDT (8:53am local time)
# output= Enron employees eligible for Metro Bus Passes or Woodlands Express Pass
# output= Brazos Valley Energy L.P.
# output= Enron Management Update - Interim CEO and COO
# output= Thursday 300pm VEPCO PPA
# output= Weekly News Briefs & Scheduling Update
# output= RAC Group Meeting with Enron
# output= Kim's expanded role within the group
# output= Energy breakfast with Forrester Research May 2nd
# output= Four WNBA Comets tickets are available for your business or personal use. Seats are in Section 104# Row D# Seats 1-4
# output= Trade Type Distribution by Transactions (TDI)
# output= Meeting on Monday November 5 at 10:00am in conference room EB3125B
# output= Outage from 11:00 P.M. until 11:30 PM on Friday
# output= GISB Contract Contingency Management Services
# output= Enron Gulf Bill - G/E 11248
# output= GMAT Review Course at Enron - 7129-00
# output= Enron not interested in transmission systems.
# output= All-Employee Meeting: 10 a.m. - 10:30am Tuesday
# output= Enron employment tax refund project - Job Creation Questionnaire
# output= Use the Questionnaire to share your thoughts on the ETS Solution Center in September.
# output= Hi, can you please load the programs that I emialed you earlier?
# output= Navy Fly Away/Coronado Island
# output= 20/20 Purchase and Sale Agreement - ENA Reps.
# output= Office vacancy ad for Wes Colwell
# output= Energy breakfast with Forrester Research May 2nd
# output= ISDA Master Agreement (Multicurrency-Cross Border)
# output= FERC Decision on LFT Services
# output= Background information for today's Corp. Policy Committee meeting
# output= Enron Legal Roundtable with ADL and Judge DeLaughter
# output= Work from Home Financial Manage Jobs
# output= Your mailbox size is currently 75421 KB.
# output= Enron employee Nick Humber on Flight 11
# output= DOMTAR (DTC)
# output= Help me understand HOW MANY Tozzini memoranda exist which address financial swaps and derivatives.
# output= Non-Exempt Employee Developmental and Performance Reviews
# output= Changes to Autohedge on EnronOnline effective Monday, October 22 2001
# output= Enron Center Security Update - October 25th
# output= Manager's Journal: What Enron Did Right 11/19/2001
# output= Dynegy's Complaint against Commonwealth Edison Company
# output= Lavorato to review and validate gas curves for 12/01/01 forward
# output= UBSW Energy Launch Timeline: Hart-Scott-Rodino Application
# output= Here are our numbers. If someone in the fundy group could send me your numbers# I would like to know where the discrepancies are.
# ...
# output= Enron "Who wants to be a Millionaire?" Game
# output= Homeowner Question or Interested Party?
# output= Netco Re-start/Integration Plans - January 2002
# output= Weather Prediction Lab Q&A with Vince
# output= European Equity Trading Expanded into European Markets
# output= Enron History by Ken Layne Layne
# output= Utilicorp Application for Sub-user Passwords
# output= Weekly Newsquiz - Fall 2001
# output= Enron Long Term Incentive Plan administrator: I would like to explore opportunities in venture capital without triggering non-compete provisions
# output= Christie Patrick is a VP of Government Affairs
# output= Migration to UBSW Energy
# output= Bermuda Corporation - Networking
# output= List of EGM employees we would like to reinstate.
# output= REMINDER - February 15 2001
# output= Enron CEO's Employment Contract - Change of Control
# output= Leach to BG&E space
# output= Status Call - tomorrow at 100 central
# output= Enron North Americawire request for $159.86
# output= 1-30 31-60 61-90 >90 100%
# output= Lance Schuler letter to Keith
# output= Global Risk Management Operations Mid-Year PRC
# output= First Draft of the 2015 Labor Day Rally/Labor Day Program
# output= S&P Working Group Discussion List: BME/RT Pricing Issues
# output= Group proposal looks good for Brad Romine
# output= Airshow Hours: Gates Open Saturday 8:00 a.m.-6:00 p.m. - No admittance to airshow after 3:00pm.
# output= Top ten shippers by revenues for TW
# output= # Ben Love's health precludes him from making any follow-up calls.
# output= Heirloom Tomato Bowls - S/5 83-4006151 1
# output= Dear AMU Student: Thank you for your provisional acceptance into the Master of Arts program.
# output= Kara Ausenhus is the Assistant for Government & Regulatory Affairs Group at ENA.
# output= This contract is for 1 day on Feb 23rd
# output= Ask a question on eSpeak with Billy Lemmons May 10 at 10 a.m. ET
# output= NAAs outside legal counsel for derivatives issues
# output= Nogid/Freeland Equity Swaps
# output= Cancellation of ECN 8c1 Meeting
# output= Congratulations on the birth of your daughter!
# output= Provision guaranteeing lease payments in the event savings are insufficient
# output= NE Membership Mixer at MacMenamin's South Street Seaport - NYC!
# output= ISDA Master Agreements (Multicurrency-Cross Border)
# output= Section 10.2 Effect of Force Majeure
# output= Enron Energia Industrial de Mexico B.V. Company Number 1627
# output= California Senate & SoCal Edison
# output= Super Saturday candidates: Kudos!
# output= Jeff McMahon appointed CFO of Enron
# output=  maintenance work for NYISO web sites on August 22 and 23
# output= Purchase and Sale Agreement/Letter from LRCI to the Police Jury
# output= Off Peak Deals in Deal Blotter - Question
# output= Right of Way Services Agreement - ROWSA
# output= AEP license agreement - POPS
# output= Bankers Trust Company was acquired by Deutsche Bank AG 6/4/99
# output= Your e-mail is being held at the MailSweeper server
# output= eSource presents Lexis-Nexis training
# output= WSS meter number - VNG
# output= KM Proposal/Risk Management Meeting
# output= Transwestern Marketing's suggested position on potential take-away capacity at SoCal Needles
# output= Internal Enron "Gross Numbers" for Enron 2006
# output= No urgency in finalizing master netting agreements
# output= Waiver Period - End of Waiver
# output= More than one petition filed before bankruptcy court for severance
# output= The Bridge/Telerate system will not be migrated to UBS infrastructure
# output= November 11th Party for Research Group
# output= Enron Partners Filing for Bankruptcy
# output= Comments on ISDA and CSA SchedulesDear Adele,
# output= Enron Wholesale Services attorney
# output= Rotation Information for Analyst and Associate Program
# output= v2.0 of the ClickAtHome Portal is now available! Log into www.clickathome.net now from work or home! Access the PEP System through the portal!
# output= Assignment Questions for EL PASO and OCC
# output= Energy risk management meeting at 3:00 p.m.
# output= February Speaker: Dr. John Lienhard - Innovation
# output= King & Spalding power transaction deal team
# output= PSIM: A Power Simulation Tool
# output= v2.0 of the ClickAtHome Portal is now available! Log into www.clickathome.net now from work or home! Access the PEP System through the portal!
# output= $25 contribution each for the Playstation 2
# output= Kenneth Lovejoy has joined Enron Corp. EES
# output= Weekly Report from PREPA Operations Office
# output=  tentative schedule for the rest of the month
# output= TNRCC to allow portable emissions test at Spraberry C/S
# output= Can you track down the $250 million tax issue?
# output= Enron and the United Way of the Texas Gulf Coast announce a new partnership
# output= Eugenio Navarrette - MS Excel
# output= Viruses can cause data loss and service outage.
# output= 138 MMBtu cut on ANR Contract 104684
# output= Sulfur River assets: 1200 miles of gathering in East Texas
# output= More questions for Lincoln Bidders
# output= FIA OpTech 2002 Tuesday, April 16th - New York Marriott Marquis Hotel Register before March 15 and save $55!
# output= Friday Peer Group Performance Reports - PGA Board Meeting
# output= Lexis-Nexis Basics and Due Diligence Clinics
# output= Assignment of PSA balances created with deferrals of restricted stock
# output= Talking Points for Ken Lay and Chairman Greenspan
# output= ECCL Finalizes ISDA Master Agreement with MSCS
# output= Changes to the Executive Summary/Roles & Responsibilities section
# output= EEOS IBIT Schedule - (35.9)
# output= NPC tag under West Desk
# output= Raptor issues - Kristina
# output= Penn Fuel asset management deal for January
# output= Save money on these games on launch day!
# output= GA's "value" to our pipeline group
# output= New legal review procedure for physical power contracts
# output= Power Outage Database Outage PDF
# output= Force Majeure for September 11 - 15th
# output= Friday Night WINE BAR at Christopher's
# output= Financial Post Modeling Meeting with James Scribner - Tuesday morning
# output= Take a look at the rates for Cayman
# output= Enron is one of the traders that have my company listed as one of three or four minority businesses
# output= Master Netting Agreement Form Notices - Today's
# output= Bankruptcy Informal Fund Meeting
# output= New UBS Warburg office space Q&A
# output= MOCK test plans for processing ETX deals
# output= Contracts - List with contract numbers
# output= ISDA Agreement with Enron guaranty attached
# output= Hi from your "GOD-GOD"
# output= Financial Institutions Briefing - Q1 2018
# output= Enron Corp. Credit Support Detailed Development and Financings
# output= Birthday wishes for Prentice
# output= Master Firm Credit Worksheets - Credit Guaranty
# output= Carpet cleaning at World Trade Center
# output= STCA Interdesk Swaps for Monday and Tuesday
# output= Meeting with Dad at Grotto (on Westheimer)
# output= global@mailonline.com
# output= JER Partners 1000/d Contract modification
# output= Assignment/Markdown Comparison of Markup/Copy
# output= Hi Tana. How have you been?
# output= We pulled the log... found the guy... and told him to knock it off
# output= Enron Chairman of the Board and Chief Executive Officer
# output=  ABB Break Out Contract Negotiations
# output= Enron Conference Call: An Update
# output= Tufco contract adjustment - July 2000
# output= ENA negotiating ISDA with Statoil
# output= EWS Brown Bag Lunch Series Featuring THE MAP GUYS
# output= Global Marketing Management Group news releases and blog posts
# output= TBA for Credit Lyonnais and Monument Derivatives
# output= PriceWaterhouseCoopers Good for a laugh!
# output= 2001 Chairman's Award Nominations - Friday October 12
# output= ECS Credit Management Council ("ECS Council")
# output= Enron Field tour contact information
# output= No one at DPW interested in putting a contract in place
# output= Make sure you are using Pinnacle West and not APS when you are putting these deals in
# output= Gem Broker - Janette
# output= Market Manager Software - @theMoment Inc.
# output= Diane's Farewell Whingding
# output= Gadgets & Gizmos - Wed. Wed.
# output= HVB America Reception & Dinner - October 24 2001 - Houston, Texas
# output= Weekly Credit Watch Listings for 10/08/01
# output= NYISO Technical Bulletin # 75 - Procedure to apply for CLR or ELR classification - September 14 2001
# output= Can you work with Sara to get ISDA Masters for this guy in the Audit group?
# output= Enron Chairman of the Board and Chief Executive Officer
# output= Commercial Support VP - Diamond-Cluster
# output= 250 randomly selected U.S.-based employees will receive Fortune's "100 Best Companies to Work for in America" survey.
# output= Enron IT Comments on "Enron Corp. Mandate"
# output= PRC rep: Please send the following information to me by December 1
# output= Good News Developments regarding Enron Property Sales
# output= Enron Conference Call: An Update
# output= Conflict Management Information Liaison
# output= Migration Protocol for Enron Employees at UBS Warburg Energy
# output=  GE consent for Pastoria (GE PRO consent)
# output= Hey EZ - Good to see you again!
# output= Weekly Report from EES Gas Group
# output= Assignment Agreement Spreadsheets - 100 and 60.40
# output= What does being short/long a position mean? What is curve shift?
# output= Lotus Notes Weekly Newsquiz
# output= REMINDER - ect.enron.com and ees.enrons.com Email domains will be decommissioned January 18th.
# output= Enron merger with Dynegy
# output= Enron Principal Investments (EPI)
# output= Mark Thomas and Mike Presley resign from Netco Market Risk/Research Group
# output= Enron Pay stub Form Required by October 15 2001
# output= Duke Outreach Team USA
# output= Contract Termination Notice/Payment Notification
# output= Harvard Master's Program in Criminal Justice
# output= Conditional Offers accepted by TD Waterhouse
# output= Model Quality Assurance Consultant
# output= Court of Appeals for the Federal Circuit rules Prozac patent invalid for double patenting
# output= Legal Temp IDs 9# 10# and 11 - Please add calendar access rights
# output= Public Affairs Group Gatherings
# output= Letter from the Mayor of San Francisco
# output= Happy Birthday to my "Mature"
# output= Draft Memo 3/16/00
# output= Weekly meetings would be good for team unity. "Lessons" would be useful.
# output= EnPower Index Deals - Mid-C
# output= LSU Analyst Resume - Vince
# output= Here is a first cut at where things stand on projects
# output= Financial LPG trade on EnronOnline
# output= Group meeting on Wednesday, March 1
# output= Augustin David's call from BA
# output= Migration of UBSWE Employees
# output= Your Windsor address is to be used on your tax returns
# output= Your office moves are scheduled for October 5th - 13th.
# output= hi - thank you for meeting with me last week!
# output= JDF Kick-off Luncheon - Wednesday September 6th - 11:30am
# output= Your insurance expired on 10/4/2001
# output= How is Houston? Will you have problem getting out tomorrow?
# output= Revised LOI - Please read and comment
# output= Questions from Gas Daily regarding disaster preparedness
# output= DPR for 11/30/01
# output= Girons leaving for Baton Rouge on New Year's Eve
# output= Travel on Orbitz: December 21 - December 26
# output= New meters to add to the database with unique identifiers.
# output= Outstanding business expenses - iPayIt/XMSM
# output= Stephanie Sever from $6#500 to $7#000 Christopher Walker from $2#000 to $4#000
# output= Lexis-Nexis Basics and Due Diligence Clinics
# output= Weekly Report #21-01-01
# output= Performance Evaluation Program feedback forms - November 17th
# output= Accountant Response Form (Resolution) - 10/24/01/01
# output= Hi, I hope things are well with you and everyone else in Research
# output= CESG Panel: Will you moderate a CESG Annual Retreat?
# output= You should have received a copy of your title policy during your closing
# output= MidAmerican and GMS Gas Logistics Contacts
# output= PricewaterhouseCoopers LLP privacy policy
# output= Migration for UBS Group 2/06/02
# output= U.S. government is investigating hundreds of relatives of those involved in 9/11 attacks.
# output= Transition talks with Andrea Lang
# output= Lexis-Nexis Basics and Due Diligence Clinics
# output= UBS Warburg Payroll/Benefits Forms
# output= Carr Futures AGMAIL Charts 2001
# output= Michael's winter report from his teachers was good.
# output= NYISO web servers will be upgraded on October 17 2001
# output= List of Services Market Data Will Support moving forward
# output= Fastow Credit Worksheets
# output= Make sure your Stack Managers are accessing the correct database
# output= NA Performance Assurance Letter of Credit & Other Special Provisions
# output= Comments on El Paso's proposal to allocate defined receipt point rights to shippers
# output= Comments on El Paso's Receiving Point Reallocation Proposal are Due on Thursday May 17th.
# output= Whalley open on Thursday?
# output= Outage on Envision from 5:00 p.m. through 6:00 a.m.: Hardware maintenance on the Envision system. Outage on FileNet IDM Desktop
# output= 2002 EREC Earnings and Cash Flow Plans
# output= DeLay letter to Ken and Jeff
# output= Interviewee was so hot all I could think of was how good she must taste
# output= New Power vs. TXU: Who's the price leader?
# output= S&P Downgrades Enron's Long-term Credit Rating
# output= R McDonald's EGM Group
# output= Hearings went from 9AM-5PM
# output= UBS HR Presentation - Thursday 1/24/02 - 2:00 PM
# output= One Texas Soldier is better than one thousand Taliban
# output= Outage on Envision web queries: Feb. 2 - 9:00 a.m.
# output= Business at Enron in Portland will not be affected by Jeff Skilling's departure
# output= Can you help me with a Canadian ISDA Form Question?
# output= Enron Americas Staff Meeting - 4:00-5:00 p.m.
# output= 80% likely NRC inspection in late November or early December
# output= Annual Compliance Meeting - October 25 2001 8:30 am - 10:30am
# output= Enron Options Extender Request
# output= "Code Reports" for Tuesday
# output= Your mailbox size is currently 78217 KB.
# output= Watch the Enron Building lobby on Tuesday April 24th from 11:30am to 1:00pm for information on innovative technology!
# output= Enron Fitness Center payroll deduction
# output= One-of-a-kind words
# output= EXCEL Class - Please email your questions
# output= Operations Controller Forum - EEL
# output= Benefits and Planning Documents
# output= Weather is beautiful! picnic planned for Saturday
# output= Your Pipeline Profile - Take a minute to fill in the attached document
# output= Lousiana Pacific Deal # 421598.1
# output= Rate changes must be put in CBS
# output= Invitation for July trip to Tim
# output= Draft Settlement and Release Agreement for Westfield #1
# output= Rotation of Susan Bailey, Susan Flynn and Marie Heard
# output= New interconnect between TW and Questar
# output= Risk Management positions as of Sept. 1st
# output= CES Daily Volume Purchase from ENA
# output= Revised gas purchase agreement and Collection Facilities Agreement
# output= Enron Corporate Rates in New York
# output= Enron Wholesale Services Group 6/20/End of Meeting Log
# output= Assnex A mail-out
# output= The EOL cluster going down from 3:30 to 4:00pm
# output= Your Admittance to the Partnership
# output= Bay Guardian Weekly Newsquiz
# output= Enron Merger with Dynegy
# output= RAC associate's Proposal for Company Management
# output= Questions from Allegheny regarding the Gleason plant
# output=  TW's transfer of gas from PG&E/Topock receipt/delivery point to PG&e Park N' Ride point
# output= Real time weighted average price for fixed price products for May can be found on the Fundy site.
# output= ENDA approval for Australian counterparties
# output= Term Sheet Revised for EPMI Proposed Power Purchase Order
# output= Plaintiffs pressing for a deposition on December 5 from TW corporate rep
# output= Enron merger with Dynegy
# output= These purchases expire with no evergreen flag
# output= SoCalGas unbundling order - Transwestern Response
# output= Bank of America N.A. and Enron North America Corp.
# output= Gulf States Bank guaranty
# output= New Year's Eve at the Firehouse
# output= Power Supplies Management e-mail distribution list
# output= Dawn and Gary Wilson are the proud parents of a baby girl
# Index(['input_text', 'target_text', 'ann0', 'ann1', 'ann2', 'gen_subject'], dtype='object')

# %%
test_df.to_csv('/content/test_result_df.csv', index=False)

# %%
test_df = pd.read_csv('/content/test_result_df.csv')
print(test_df.shape)
test_df = test_df.rename(columns={'target_text': 'subject'})
print(test_df.columns)
# Out:
# (1906, 6)
# Index(['input_text', 'subject', 'ann0', 'ann1', 'ann2', 'gen_subject'], dtype='object')

# %%
# !pip install evaluate
# !pip install rouge_score
# !pip install sacrebleu
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.25.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.15.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.2
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.25.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.4)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=3da8d03b6649e05e606e1ba5fd9ddd8eed85e890fec5ba19b34aebf9028a61ac
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 4.0 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2024.5.15)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.25.2)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-2.10.1 sacrebleu-2.4.2

# %%
from evaluate import load
from collections import defaultdict
from tqdm import tqdm

def metric(data):
    sub,ann0,ann1,ann2,gen_subject  = ["subject","ann0","ann1","ann2","gen_subject"]
    rouge = load("rouge")
    meteor = load("meteor")
    bleu = load("sacrebleu")
    score = defaultdict(int)

    for _,x in tqdm(data.iterrows(),total=len(data)):

        rouge_s = rouge.compute(predictions=[x[gen_subject]],references=[x[sub]])
        rouge_h = rouge.compute(predictions=[x[gen_subject]] ,references=[[x[ann0],x[ann1],x[ann2]]])

        score["rouge_1_sub"] += rouge_s['rouge1']
        score["rouge_2_sub"] += rouge_s['rouge2']
        score["rouge_L_sub"] += rouge_s['rougeL']

        score["rouge_1_human"] += rouge_h['rouge1']
        score["rouge_2_human"] += rouge_h['rouge2']
        score["rouge_L_human"] += rouge_h['rougeL']


        meteor_s = meteor.compute(predictions=[x[gen_subject]],references=[x[sub]])
        meteor_h = meteor.compute(predictions=[x[gen_subject]] ,references=[[x[ann0],x[ann1],x[ann2]]])

        score["meteor_sub"] += meteor_s["meteor"]
        score["meteor_human"] += meteor_h["meteor"]

        bleu_s = bleu.compute(predictions=[x[gen_subject]],references=[x[sub]])
        bleu_h = bleu.compute(predictions=[x[gen_subject]],references=[[x[ann0],x[ann1],x[ann2]]])

        score["bleu_s"] += bleu_s["score"]
        score["bleu_h"] += bleu_h["score"]

    print("The evalution scores are as follows:")

    for name,val in score.items():
        print(f"{name}: {val/len(data)}")

# %%
metric(test_df)
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/6.93k [00:00<?, ?B/s]
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Downloading builder script:   0%|          | 0.00/8.15k [00:00<?, ?B/s]
# 100%|██████████| 1906/1906 [11:33<00:00,  2.75it/s]
# The evalution scores are as follows:
# rouge_1_sub: 0.22678015397515078
# rouge_2_sub: 0.09689332892753086
# rouge_L_sub: 0.21278668058998593
# rouge_1_human: 0.4308012138718197
# rouge_2_human: 0.2519320284304441
# rouge_L_human: 0.4021245614683105
# meteor_sub: 0.22936017913893506
# meteor_human: 0.44508801372083123
# bleu_s: 6.193269363734809
# bleu_h: 6.255868812251805

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
#testing save here
# Out:
# Mounted at /content/drive
